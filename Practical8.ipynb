# %% [markdown]
# # Titanic Data Visualization with Seaborn

# %% [markdown]
# ### Step 1: Load the Titanic Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Display the first few rows
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Step 2: Explore Patterns in the Data

# %% [markdown]
# #### 1: Survival based on gender

# %%
sns.countplot(x='sex', hue='survived', data=titanic)
plt.title('Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# #### 2: Class vs Survival

# %%
sns.countplot(x='class', hue='survived', data=titanic)
plt.title('Survival by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# #### Age vs Fare (Scatter Plot)

# %%
sns.scatterplot(x='age', y='fare', hue='survived', data=titanic)
plt.title('Age vs Fare (Survival colored)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### Step 3: Plot a Histogram of Ticket Fare

# %%
# Drop NA fares
titanic_fare = titanic['fare'].dropna()

# Plot histogram
plt.figure(figsize=(8,5))
sns.histplot(titanic_fare, kde=True, bins=30, color='skyblue')
plt.title('Distribution of Ticket Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation Matrices of Titanic Dataset Features

# %%
corr = titanic.corr() 
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr = titanic.corr() 
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Age Distribution by Gender and Survival Status

# %%
sns.swarmplot(x='sex', y='age', data=titanic, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Age Distribution of Passengers by Gender

# %%
sns.stripplot(x='sex', y='age', data=titanic, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Age Distribution by Gender and Survival Status

# %%
sns.violinplot(x='sex',y='age',data=titanic,hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Age Distribution by Gender and Survival Status

# %%
sns.boxplot(x='sex', y='age', data=titanic, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Rugplot Showing Distribution of Passenger Fares

# %%
sns.rugplot(titanic['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# ## Joint Distribution of Fare and Age

# %%
# For Plot 1 
sns.jointplot(x=titanic['age'],y=titanic['fare'],kind='scatter') 
# For Plot 2 
sns.jointplot(x=titanic['age'],y=titanic['fare'],kind='hex')
